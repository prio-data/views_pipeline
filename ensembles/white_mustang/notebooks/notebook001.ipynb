# %%
import pandas as pd
pd.read_pickle('../data/generated/predictions_36_forecasting_lavender_haze20240826_150522_blank_space20240802_113058.pkl')
# Out:
# feature                step_pred_1  step_pred_2  step_pred_3  step_pred_4  \
# month_id priogrid_gid
# 535      62356            0.000148     0.000110     0.000111     0.000144
#          79599            0.000133     0.000109     0.000090     0.000147
#          79600            0.000142     0.000119     0.000115     0.000211
#          79601            0.000131     0.000110     0.000091     0.000146
#          80317            0.000128     0.000102     0.000089     0.000147
# ...                            ...          ...          ...          ...
# 570      190496                NaN          NaN          NaN          NaN
#          190507                NaN          NaN          NaN          NaN
#          190508                NaN          NaN          NaN          NaN
#          190510                NaN          NaN          NaN          NaN
#          190511                NaN          NaN          NaN          NaN
#
# ...
