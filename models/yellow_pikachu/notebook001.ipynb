# %%
import pandas as pd
import numpy as np
df = pd.read_parquet('./data/raw/raw.parquet')

# %%
df.dtypes
# Out:
# ged_sb_dep      float64
# ged_gte_1       float64
# treelag_1_sb    float64
# treelag_1_ns    float64
# treelag_1_os    float64
# treelag_2_sb    float64
# treelag_2_ns    float64
# treelag_2_os    float64
# dtype: object

# %%
pd.read_parquet('../orange_pasta/data/raw/raw.parquet').dtypes
# Out:
# ged_sb_dep                float64
# ln_ged_sb                 float64
# ln_pop_gpw_sum            float64
# decay_ged_sb_1            float64
# decay_ged_sb_25           float64
# decay_ged_os_1            float64
# splag_1_1_sb_1            float64
# splag_1_decay_ged_sb_1    float64
# dtype: object
