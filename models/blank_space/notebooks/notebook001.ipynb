# %%
import pandas as pd
pd.read_parquet("../data/generated/generated.parquet")
# Out:
#                        step_pred_1  step_pred_2  step_pred_3  step_pred_4  \
# month_id priogrid_gid
# 530      62356            0.256551     0.227557     0.488913     0.209929
#          79599            0.099671     0.146406     0.054649     0.092609
#          79600            0.099671     0.170610     0.050000     0.178800
#          79601            0.107438     0.146406     0.047399     0.089084
#          80317            0.130778     0.185889     0.124451     0.135041
# ...                            ...          ...          ...          ...
#          190496           0.058204     0.176467     0.041248     0.106065
#          190507           0.069155     0.182948     0.038348     0.134397
#          190508           0.063567     0.227789     0.097442     0.265889
#          190510           0.071951     0.122570     0.012769     0.070929
#          190511           0.069119     0.179973     0.032913     0.134397
#
# ...
